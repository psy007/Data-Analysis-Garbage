# %%
import matplotlib.pyplot as plt
header=[chr(n) for n in range(65, 74)]
list1 = [n+1 for n in range(10)]
list2 = [n+6 for n in range(10)]
plt.plot(list1,list2, 'g')
plt.xlabel("This is x Label")
plt.ylabel("This is y label")
plt.title("This is title")
plt.show()

# %%
# Create plot axes for the first line plot
plt.axes([0.05,0.05,0.425,0.9])

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(list1, list2, color='blue')

# Create plot axes for the second line plot
plt.axes([0.525,0.05,0.425,0.9])

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(list1, list2, color='red')

# Display the plot
plt.show()

# %%
# Create a figure with 1x2 subplot and make the left subplot active
plt.subplot(2,1,1)

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(list1, list2, color='blue')
plt.title('Physical Sciences')

# Make the right subplot active in the current 1x2 subplot grid
plt.subplot(2,1,2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(list1, list2, color='red')
plt.title('Computer Science')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()
plt.show()

# %%
# Create a figure with 2x2 subplot layout and make the top left subplot 
plt.subplot(2,2,1)

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(list1, list2, color='blue')
plt.title('Physical Sciences')

# Make the top right subplot active in the current 2x2 subplot grid 
plt.subplot(2,2,2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(list1, list2, color='red')
plt.title('Computer Science')

# Make the bottom left subplot active in the current 2x2 subplot grid
plt.subplot(2,2,3)

# Plot in green the % of degrees awarded to women in Health Professions
plt.plot(list1,list2, color='green')
plt.title('Health Professions')

# Make the bottom right subplot active in the current 2x2 subplot grid
plt.subplot(2,2,4)

# Plot in yellow the % of degrees awarded to women in Education
plt.plot(list1, list2, color='yellow')
plt.title('Education')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %%
import pandas as pd
df= pd.read_csv('bokeh.csv')
df.set_index('Year')
print(df.head())
year = df['Year']
computer_science = df['computer']
physical_sciences = df['physics']
health = df['socail']
education = df['art']
# Out:
#    Year    physics   computer     socail        art
# 0  1900   0.000000  27.980244  85.559651  85.256378
# 1  1901  38.650324   2.333902  75.060460  21.373240
# 2  1902  62.374321  33.387951  76.465644  50.772845
# 3  1903  66.157113  74.222991  43.179391  62.823148
# 4  1904  92.938758  65.735819  68.111431  49.830707

# %%
# Plot the % of degrees awarded to women in Computer Science and the Physical Sciences
plt.plot(year,computer_science, color='red') 
plt.plot(year, physical_sciences, color='blue')

# Add the axis labels
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

# Set the x-axis range
plt.xlim(1990,2010)

# Set the y-axis range
plt.ylim(0,50)

# Add a title and display the plot
plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')
plt.show()

# Save the image as 'xlim_and_ylim.png'
plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# # Below code uses plt.axis to set the limit

# %%
# Plot in blue the % of degrees awarded to women in Computer Science
plt.plot(year,computer_science, color='blue')

# Plot in red the % of degrees awarded to women in the Physical Sciences
plt.plot(year, physical_sciences,color='red')

# Set the x-axis and y-axis limits
plt.axis((1990,2010,0,50))

# Show the figure
plt.show()

# Save the figure as 'axis_limits.png'
plt.savefig('axis_limits.png')
